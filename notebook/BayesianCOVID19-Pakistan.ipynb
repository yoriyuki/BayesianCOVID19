# %%
import pystan
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import arviz as az
import pickle

# %%
#### Preprocecing ###

# %%
jh_dir = "../../COVID-19"

# %%
Confirmed = pd.read_csv(jh_dir + "/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")

# %%
df = Confirmed.groupby("Country/Region").sum()
df = df.drop(["Lat", "Long"], 1)
df = df.T
df = df.set_index(pd.to_datetime(df.index))
confirmed = df
confirmed = confirmed.cummax()

# %%
df = pd.read_csv(jh_dir + "/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")
df = df.groupby("Country/Region").sum()
df = df.drop(["Lat", "Long"], 1)
df = df.T
df = df.set_index(pd.to_datetime(df.index))
recovered = df.cummax()

# %%
df = pd.read_csv(jh_dir + "/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
df = df.groupby("Country/Region").sum()
df = df.drop(["Lat", "Long"], 1)
df = df.T
df = df.set_index(pd.to_datetime(df.index))
death = df.cummax()

# %%
### Data Preparation ###

# %%
country = 'Pakistan'
epoch = pd.to_datetime('2020-03-01')
last = pd.to_datetime('2020-04-26')
C0 = confirmed.loc[epoch:last, country].values
R0 = (recovered).loc[epoch:last, country].values
D0 = death.loc[epoch:last, country].values
P = 212_200_00
iteration=2000
repeat = 1000

# %%
data = {'T': C0.shape[0], 'T0': 0, 'P': P, 'C0': C0, 'R0': R0, 'D0':D0}

# %%
### Model ###

# %%
sm_const = pystan.StanModel(file="const.stan")
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_4eac12a2ea1ef4aed77a9d1e0d898b25 NOW.

# %%
sm_every = pystan.StanModel(file="everyday.stan")
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_babe7ed46ab03a4d90abb7d0b91b2ac7 NOW.

# %%
# Train the model and generate samples
inits = 'random'
fit_const = sm_const.sampling(data=data, iter=iteration, init=inits)
fit_const
# Out:
# WARNING:pystan:Truncated summary with the 'fit.__repr__' method. For the full summary use 'print(fit)'
# Warning: Shown data is truncated to 100 parameters
# For the full summary use 'print(fit)'
#
# Inference for Stan model: anon_model_4eac12a2ea1ef4aed77a9d1e0d898b25.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#               mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# init_inf     26.95    0.05   3.84  19.89  24.32  26.76  29.48  34.88   4953    1.0
# b             0.11  2.1e-5 1.3e-3   0.11   0.11   0.11   0.11   0.11   3966    1.0
# q              1.0  2.4e-5 1.7e-3   0.99    1.0    1.0    1.0    1.0   5245    1.0
# NI[1]         5.15    0.03   1.62   1.92   4.03   5.16   6.26   8.35   3820    1.0
# NI[2]         6.33    0.02   1.67   3.06   5.18   6.34   7.45   9.61   4853    1.0
# NI[3]         6.54    0.03   1.88   2.83   5.33   6.54   7.78  10.25   3351    1.0
# NI[4]         7.28    0.03   2.03   3.38   5.91   7.24   8.65  11.25   3519    1.0
# NI[5]         8.79    0.03   2.09   4.79   7.34   8.75  10.19   12.9   4933    1.0
# NI[6]         9.19    0.04   2.32   4.87   7.54   9.17  10.75  13.72   4346    1.0
# NI[7]        10.23    0.04   2.45    5.5   8.58  10.13  11.96  15.17   4876    1.0
# NI[8]        11.49    0.04    2.6   6.37   9.75  11.48  13.25  16.61   4506    1.0
# NI[9]        17.34    0.03   2.52   12.5  15.62  17.31  19.07  22.37   5503    1.0
# NI[10]       16.02    0.04   2.95  10.26  14.03  15.98  17.94  21.88   6454    1.0
# NI[11]       16.45    0.04   3.24  10.27  14.27  16.45  18.58  22.92   5480    1.0
# NI[12]       21.91    0.04   3.15  15.86   19.8  21.89  24.01  28.18   5901    1.0
# log_lik[20] -53.13    0.08   5.53 -64.55 -56.65 -52.93 -49.37 -42.74   4981    1.0
# log_lik[21]   -4.2    0.02   1.14  -7.05  -4.82  -3.93  -3.33  -2.85   4843    1.0
# log_lik[22]  -4.78    0.02   1.12  -7.53  -5.41  -4.55  -3.93   -3.3   4476    1.0
# log_lik[23]   -4.0    0.01   0.78  -5.97  -4.37  -3.79   -3.4  -3.21   3316    1.0
# log_lik[24]  -3.45  8.9e-3   0.39  -4.53  -3.54   -3.3   -3.2  -3.18   1889    1.0
# log_lik[25]  -6.43    0.02   1.57 -10.12   -7.3   -6.2   -5.3  -4.06   5496    1.0
# log_lik[26]  -9.95    0.03   2.32 -15.13  -11.3  -9.72  -8.28  -6.09   5924    1.0
# log_lik[27]  -3.75    0.01   0.56  -5.31   -3.9  -3.54  -3.38  -3.32   2807    1.0
# log_lik[28]  -3.84    0.01   0.68  -5.59  -4.13  -3.59  -3.32  -3.23   3125    1.0
# log_lik[29]  -3.64  8.4e-3   0.44  -4.86  -3.76  -3.48  -3.35  -3.31   2711    1.0
# log_lik[30]  -9.79    0.03   2.21 -14.47 -11.15  -9.57  -8.17  -6.17   5169    1.0
# log_lik[31]  -4.47    0.01   0.89  -6.71  -4.89  -4.23   -3.8  -3.52   3803    1.0
# log_lik[32] -17.92    0.04   3.49 -25.36 -20.06 -17.67 -15.47 -11.83   6479    1.0
# log_lik[33]  -9.26    0.03   2.19  -14.2 -10.61   -9.0  -7.65  -5.76   5675    1.0
# log_lik[34]   -6.0    0.02   1.66  -9.92  -6.95  -5.75  -4.72  -3.59   5885    1.0
# log_lik[35] -14.21    0.04   3.13 -21.05 -16.12 -13.96 -11.98  -8.85   6269    1.0
# log_lik[36] -71.97    0.09   7.33 -86.65  -76.8 -71.63 -67.13 -57.82   6619    1.0
# log_lik[37]  -4.57    0.01   0.87  -6.86  -4.93  -4.33   -3.9  -3.72   4235    1.0
# log_lik[38]   -4.2    0.01   0.67  -6.08  -4.43  -3.96  -3.71  -3.63   3767    1.0
# log_lik[39]   -4.9    0.02   1.11  -7.72  -5.47  -4.64  -4.03  -3.64   4755    1.0
# lp__         7.4e4    0.14   5.57  7.4e4  7.4e4  7.4e4  7.4e4  7.4e4   1535    1.0
#
# Samples were drawn using NUTS at Tue Apr 28 15:43:38 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
# Train the model and generate samples
inits = 'random'
fit_every = sm_every.sampling(data=data, iter=iteration, init=inits)
fit_every
# Out:
# WARNING:pystan:29 of 4000 iterations ended with a divergence (0.725 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:Truncated summary with the 'fit.__repr__' method. For the full summary use 'print(fit)'
# Warning: Shown data is truncated to 100 parameters
# For the full summary use 'print(fit)'
#
# Inference for Stan model: anon_model_babe7ed46ab03a4d90abb7d0b91b2ac7.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#            mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# init_inf    1.7    0.01   0.82   0.49    1.1   1.55   2.13   3.71   5428    1.0
# b_beta     1.04  3.2e-3   0.27   0.58   0.85   1.02   1.22   1.64   7433    1.0
# b[1]       0.65  6.6e-3   0.48   0.07    0.3   0.54   0.88   1.93   5452    1.0
# b[2]       0.55  5.7e-3   0.43   0.06   0.25   0.45   0.74   1.66   5800    1.0
# b[3]       0.38  4.9e-3   0.34   0.02   0.14   0.29   0.52   1.25   4711    1.0
# log_lik[50]  -3.51    0.01   0.66  -5.41  -3.67  -3.26  -3.09  -3.04   2064    1.0
# log_lik[51]  -4.95    0.01   0.73   -7.0  -5.12  -4.68   -4.5  -4.44   2731    1.0
# log_lik[52]  -4.52    0.01   0.67  -6.49  -4.68  -4.26  -4.09  -4.04   2801    1.0
# log_lik[53]  -4.91    0.01    0.7  -6.98  -5.07  -4.64  -4.46  -4.41   2531    1.0
# log_lik[54]  -4.74    0.01   0.69  -6.65  -4.91  -4.47   -4.3  -4.25   3105    1.0
# log_lik[55]  -4.75    0.01   0.69  -6.78  -4.89  -4.47   -4.3  -4.25   2631    1.0
# lp__         7.5e4    0.31  10.45  7.5e4  7.5e4  7.5e4  7.5e4  7.5e4   1123    1.0
#
# Samples were drawn using NUTS at Tue Apr 28 15:46:33 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
# Save models

# %%
## Saving results

# %%
import pickle
with open("sm_const_fit-Japan.pkl", "wb") as f:
    pickle.dump({'model' : sm_const, 'fit' : fit_const}, f, protocol=-1)
    # or with a list
    # pickle.dump([model, fit], f, protocol=-1)
# Out:
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import pickle
with open("sm_every_fit-Japan.pkl", "wb") as f:
    pickle.dump({'model' : sm_every, 'fit' : fit_every}, f, protocol=-1)
    # or with a list
    # pickle.dump([model, fit], f, protocol=-1)
# Out:
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
### Load modesl

# %%
with open("sm_const_fit-Japan.pkl", "rb") as f:
    data_dict = pickle.load(f)
    # or with a list
    # data_list = pickle.load(f)
sm_const = data_dict['model']
fit_const = data_dict['fit']
# fit = data_list[1]

# %%
with open("sm_every_fit-Japan.pkl", "rb") as f:
    data_dict = pickle.load(f)
    # or with a list
    # data_list = pickle.load(f)
sm_every = data_dict['model']
fit_every = data_dict['fit']
# fit = data_list[1]

# %%
### model selection

# %%
data_const = az.from_pystan(fit_const, log_likelihood='log_lik')
data_every = az.from_pystan(fit_every, log_likelihood='log_lik')

# %%
az.plot_trace(data_const, var_names=['b', 'q'])
# Out:
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fab42b31210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fab42b942d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fab426b6e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fab4269ba90>]],
#       dtype=object)

# %%
loo_const = az.loo(data_const, pointwise=True)
loo_const
# Out:
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/arviz/stats/stats.py:527: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   "Estimated shape parameter of Pareto distribution is greater than 0.7 for "
# Computed from 4000 by 55 log-likelihood matrix
#
#        Estimate       SE
# IC_loo  1920.39   348.09
# p_loo    432.07        -
#
# There has been a warning during the calculation. Please check the results.
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)        3    5.5%
#  (0.5, 0.7]   (ok)         15   27.3%
#    (0.7, 1]   (bad)        14   25.5%
#    (1, Inf)   (very bad)   23   41.8%

# %%
loo_every = az.loo(data_every, pointwise=True)
loo_every
# Out:
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/arviz/stats/stats.py:527: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   "Estimated shape parameter of Pareto distribution is greater than 0.7 for "
# Computed from 4000 by 55 log-likelihood matrix
#
#        Estimate       SE
# IC_loo   441.43    21.43
# p_loo     40.47        -
#
# There has been a warning during the calculation. Please check the results.
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)        4    7.3%
#  (0.5, 0.7]   (ok)          7   12.7%
#    (0.7, 1]   (bad)        36   65.5%
#    (1, Inf)   (very bad)    8   14.5%

# %%
az.compare({'const':data_const, 'everyday':data_every})
# Out:
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/arviz/stats/stats.py:1196: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   "For one or more samples the posterior variance of the log predictive "
#          rank     waic   p_waic   d_waic        weight       se      dse  \
# everyday    0  412.636  26.0763        0             1  499.623        0
# const       1  2167.58  555.664  1754.94  3.84622e-150   19.922  489.854
#
#          warning waic_scale
# everyday    True   deviance
# const       True   deviance

# %%
df = pd.DataFrame({'const':loo_const.pareto_k, 'everyday':loo_every.pareto_k})
sns.relplot(data=df)

# %%
df.idxmax()
# Out:
# const       49
# everyday    41
# dtype: int64

# %%
def loo(sm):
    log_likelihood = 0
    for i in range(C0.shape[0]-1):
        print('\rNo, %d' % i, end='')
        data_LOO = {'T': C0.shape[0], 'T0': i+1, 'P': P, 'C0': C0, 'R0': R0, 'D0':D0}
        fit_loo = sm_const.sampling(data=data_LOO, iter=2000, init='random')
        data_loo = az.from_pystan(fit_loo, log_likelihood='log_lik')
        log_likelihood += data_loo.sample_stats['log_likelihood'].sel(log_likelihood_dim_0=i).mean()
        
    return log_likelihood

# %%
### Visualization ###

# %%
def extract(data, upto):
    index=pd.date_range(start=epoch, end=upto)
    init_inf = pd.DataFrame(data_every.posterior['init_inf'].stack(sample=('chain', 'draw')).values)
    b = pd.DataFrame(data_every.posterior['b'].stack(sample=('chain', 'draw')).values, index=index)
    q = pd.DataFrame(data_every.posterior['q'].stack(sample=('chain', 'draw')).values, index=index)
    NI = pd.DataFrame(data_every.posterior['NI'].stack(sample=('chain', 'draw')).values, index=index)
    a = pd.DataFrame(data_every.posterior['a'].stack(sample=('chain', 'draw')).values)
    d = pd.DataFrame(data_every.posterior['d'].stack(sample=('chain', 'draw')).values)
    C = NI.cumsum().shift(periods=1)
    NI0 = q*NI
    C0 = NI0.cumsum().shift(periods=1)

    return a, d, b, q, NI, NI0, C, C0

# %%
a_e, d_e, b_e, q_e, NI_e, NI0_e, C_e, C0_e = extract(data_every, upto=pd.to_datetime('2020-04-24'))

# %%
def draw(simulated, real=None, upto=pd.to_datetime('2020-04-26')):
    graph=pd.DataFrame(index=pd.date_range(start=epoch, end=upto))
    median = simulated.median(axis=1)
    upper = simulated.quantile(q=0.75, axis=1)
    lower = simulated.quantile(q=0.25, axis=1)
    if not real is None:
        graph['Real'] = real
    graph['Median'] = median
    graph['Upper'] = upper
    graph['Lower'] = lower
    sns.relplot(kind="line", data=graph, aspect=2)

# %%
draw(C0_e, real=confirmed[country])
# Out:
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:995: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanmedian1d, axis, a, overwrite_input)

# %%
draw(q_e)

# %%
draw(b_e)

# %%
draw(C_e, real=confirmed[country])
# Out:
# /Users/yoriyuki/.pyenv/versions/anaconda3-5.3.1/envs/COVID-19/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:995: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanmedian1d, axis, a, overwrite_input)

# %%
a = pd.DataFrame(data_every.posterior['a'].stack(sample=('chain', 'draw')).values)
beta = pd.DataFrame(np.array([b_e[i].values - a.iloc[i].values for i in range(len(a))]).T, index=b_e.index)

# %%
draw(beta)

# %%
beta.loc[pd.to_datetime('2020-04-24')].median()
# Out:
# 0.05174543180000959
